# %% [markdown]
# ### UI integrada del asistente
# Ejecuta la celda siguiente para cargar el panel con Ranking, Sugerencias, Tendencias y Outliers.

# %%
# Carga y muestra la UI
# %run "C:/Users/delpi/OneDrive/Tesis/ADRpy-VTOL/ADRpy/asistente_diseno/main.py"
