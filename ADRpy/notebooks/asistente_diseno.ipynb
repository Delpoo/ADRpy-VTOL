# %%
# %run "C:/Users/delpi/OneDrive/Tesis/ADRpy-VTOL/ADRpy/asistente_diseno/main.py"
# Out:
#   File ~\OneDrive\Tesis\ADRpy-VTOL\ADRpy\asistente_diseno\main.py:1
#     """
#     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 138-139: truncated \UXXXXXXXX escape
